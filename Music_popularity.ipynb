# %%
import numpy as np
import pandas as pd # for working with dataframes
import seaborn as sns # for data visualization

from matplotlib import pyplot as plt # for plotting
# %matplotlib inline
sns.set_style("whitegrid")

import warnings
warnings.filterwarnings("ignore")

# %%
# Mount Google Drive (if using Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/music/spotify_data.csv')
dataframe.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    duration_ms  time_signature
# 0       240166               3
# 1       216387               4
# 2       158960               4
# 3       304293               4
# 4       244320               4

# %%
dataframe.describe()
# Out:
#          Unnamed: 0    popularity          year  danceability        energy  \
# count  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# mean   6.590613e+05  1.838312e+01  2.011955e+03  5.374382e-01  6.396699e-01
# std    4.285492e+05  1.588554e+01  6.803901e+00  1.844780e-01  2.705009e-01
# min    0.000000e+00  0.000000e+00  2.000000e+03  0.000000e+00  0.000000e+00
# 25%    2.899408e+05  5.000000e+00  2.006000e+03  4.130000e-01  4.540000e-01
# 50%    5.798815e+05  1.500000e+01  2.012000e+03  5.500000e-01  6.940000e-01
# 75%    1.031689e+06  2.900000e+01  2.018000e+03  6.770000e-01  8.730000e-01
# max    1.473395e+06  1.000000e+02  2.023000e+03  9.930000e-01  1.000000e+00
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# mean   5.287778e+00 -8.981353e+00  6.346533e-01  9.281477e-02  3.215370e-01
# std    3.555197e+00  5.682215e+00  4.815275e-01  1.268409e-01  3.549872e-01
# min    0.000000e+00 -5.810000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00 -1.082900e+01  0.000000e+00  3.710000e-02  6.400000e-03
# 50%    5.000000e+00 -7.450000e+00  1.000000e+00  5.070000e-02  1.470000e-01
# 75%    8.000000e+00 -5.276000e+00  1.000000e+00  8.900000e-02  6.400000e-01
# max    1.100000e+01  6.172000e+00  1.000000e+00  9.710000e-01  9.960000e-01
#
#        instrumentalness      liveness       valence         tempo  \
# count      1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# mean       2.523489e-01  2.230189e-01  4.555636e-01  1.213771e+02
# std        3.650731e-01  2.010707e-01  2.685190e-01  2.977975e+01
# min        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.050000e-06  9.790000e-02  2.260000e-01  9.879700e+01
# 50%        1.760000e-03  1.340000e-01  4.380000e-01  1.219310e+02
# 75%        6.140000e-01  2.920000e-01  6.740000e-01  1.399030e+02
# max        1.000000e+00  1.000000e+00  1.000000e+00  2.499930e+02
#
#         duration_ms  time_signature
# count  1.159764e+06    1.159764e+06
# mean   2.495618e+05    3.885879e+00
# std    1.494262e+05    4.676967e-01
# min    2.073000e+03    0.000000e+00
# 25%    1.810910e+05    4.000000e+00
# 50%    2.257440e+05    4.000000e+00
# 75%    2.869135e+05    4.000000e+00
# max    6.000495e+06    5.000000e+00

# %%
print(dataframe.keys())
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'year', 'genre', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
pd.isnull(dataframe).sum()
# Out:
# Unnamed: 0          0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# year                0
# genre               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# #5. Exploratory Analysis

# %%
sns.distplot(dataframe['popularity']).set_title('Popularity Distribution')
# Out:
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
dataframe.corr()
# Out:
#                   Unnamed: 0  popularity      year  danceability    energy  \
# Unnamed: 0          1.000000   -0.199414 -0.512877     -0.015889 -0.006496
# popularity         -0.199414    1.000000  0.345821      0.098533  0.009401
# year               -0.512877    0.345821  1.000000      0.040087  0.019595
# danceability       -0.015889    0.098533  0.040087      1.000000  0.139267
# energy             -0.006496    0.009401  0.019595      0.139267  1.000000
# key                 0.003700    0.000390 -0.003480      0.031363  0.038462
# loudness           -0.022308    0.104097  0.041415      0.257174  0.781006
# mode                0.020471   -0.023837 -0.031350     -0.051711 -0.052052
# speechiness        -0.016128   -0.024700  0.028864      0.086536  0.114176
# acousticness        0.013757   -0.059181 -0.025510     -0.176456 -0.752662
# instrumentalness   -0.000215   -0.152893  0.013620     -0.169122 -0.184331
# liveness            0.010344   -0.056968 -0.015538     -0.119671  0.189117
# valence             0.066826   -0.018070 -0.100907      0.519900  0.247968
# tempo              -0.003723    0.002566  0.018774     -0.016157  0.265167
# duration_ms         0.050248   -0.118484 -0.090371     -0.025874  0.012422
# time_signature     -0.003772    0.030830  0.008465      0.183918  0.171190
#
#                        key  loudness      mode  speechiness  acousticness  \
# Unnamed: 0        0.003700 -0.022308  0.020471    -0.016128      0.013757
# popularity        0.000390  0.104097 -0.023837    -0.024700     -0.059181
# year             -0.003480  0.041415 -0.031350     0.028864     -0.025510
# danceability      0.031363  0.257174 -0.051711     0.086536     -0.176456
# energy            0.038462  0.781006 -0.052052     0.114176     -0.752662
# key               1.000000  0.026866 -0.167634     0.012875     -0.034510
# loudness          0.026866  1.000000 -0.019086     0.023126     -0.621698
# mode             -0.167634 -0.019086  1.000000    -0.020096      0.067645
# speechiness       0.012875  0.023126 -0.020096     1.000000      0.031638
# acousticness     -0.034510 -0.621698  0.067645     0.031638      1.000000
# instrumentalness  0.000226 -0.403575 -0.058789    -0.142417      0.094281
# liveness         -0.005426  0.090779  0.024801     0.282482     -0.030536
# valence           0.025928  0.294912  0.018891     0.039349     -0.103285
# tempo             0.009528  0.234027 -0.005237    -0.031945     -0.240861
# duration_ms       0.008626 -0.048474 -0.038654    -0.062396     -0.064205
# time_signature    0.010431  0.171527 -0.016730    -0.028078     -0.169551
#
#                   instrumentalness  liveness   valence     tempo  duration_ms  \
# Unnamed: 0               -0.000215  0.010344  0.066826 -0.003723     0.050248
# popularity               -0.152893 -0.056968 -0.018070  0.002566    -0.118484
# year                      0.013620 -0.015538 -0.100907  0.018774    -0.090371
# danceability             -0.169122 -0.119671  0.519900 -0.016157    -0.025874
# energy                   -0.184331  0.189117  0.247968  0.265167     0.012422
# key                       0.000226 -0.005426  0.025928  0.009528     0.008626
# loudness                 -0.403575  0.090779  0.294912  0.234027    -0.048474
# mode                     -0.058789  0.024801  0.018891 -0.005237    -0.038654
# speechiness              -0.142417  0.282482  0.039349 -0.031945    -0.062396
# acousticness              0.094281 -0.030536 -0.103285 -0.240861    -0.064205
# instrumentalness          1.000000 -0.129976 -0.315200 -0.031745     0.162870
# liveness                 -0.129976  1.000000  0.007964 -0.002809    -0.007672
# valence                  -0.315200  0.007964  1.000000  0.083034    -0.131479
# tempo                    -0.031745 -0.002809  0.083034  1.000000     0.010518
# duration_ms               0.162870 -0.007672 -0.131479  0.010518     1.000000
# time_signature           -0.056557 -0.018063  0.121755  0.061919     0.017072
#
#                   time_signature
# Unnamed: 0             -0.003772
# popularity              0.030830
# year                    0.008465
# danceability            0.183918
# energy                  0.171190
# key                     0.010431
# loudness                0.171527
# mode                   -0.016730
# speechiness            -0.028078
# acousticness           -0.169551
# instrumentalness       -0.056557
# liveness               -0.018063
# valence                 0.121755
# tempo                   0.061919
# duration_ms             0.017072
# time_signature          1.000000

# %%
sns.barplot(x = 'time_signature', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Time Signature')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Time Signature')

# %%
sns.barplot(x = 'key', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Key')

# %%
sns.barplot(x = 'mode', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Mode')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode')

# %%
sns.barplot(x = 'mode', y = 'popularity', hue = 'key', data = dataframe)
plt.title('Popularity Based on Mode and Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode and Key')

# %%
sns.jointplot(x = 'acousticness', y = 'popularity', data = dataframe)

# %%
sns.jointplot(x = 'loudness', y = 'popularity', data = dataframe)

# %%
popular_above_50 = dataframe[dataframe.popularity > 50]
sns.distplot(popular_above_50['acousticness'])
plt.title('Acoustiness for Songs with More than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Acoustiness for Songs with More than 50 Popularity')

# %%
popular_below_50 = dataframe[dataframe.popularity < 50]
sns.distplot(popular_below_50['acousticness'])
plt.title('Acoustiness for Songs with Less than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Acoustiness for Songs with Less than 50 Popularity')

# %%
sns.distplot(popular_above_50['loudness'])
plt.title('Loudness for Songs with More than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Loudness for Songs with More than 50 Popularity')

# %%
popular_below_50 = dataframe[dataframe.popularity < 50]
sns.distplot(popular_below_50['loudness'])
plt.title('Loudness for Songs with Less than 50 Popularity')
# Out:
# Text(0.5, 1.0, 'Loudness for Songs with Less than 50 Popularity')

# %% [markdown]
# #6. Feature Engineering

# %%
list_of_keys = dataframe['key'].unique()
for i in range(len(list_of_keys)):
    dataframe.loc[dataframe['key'] == list_of_keys[i], 'key'] = i
dataframe.sample(5)
# Out:
#          Unnamed: 0         artist_name  \
# 827318       968176       Grateful Dead
# 717186       805119  Olivia Newton-John
# 1056583     1312793        Way Out West
# 1078364     1345792           Allegaeon
# 282855       282855       Circa Survive
#
#                                                 track_name  \
# 827318   Samson and Delilah - Live at Oakland Coliseum ...
# 717186                                               Magic
# 1056583          The Doors Are Where the Windows Should Be
# 1078364                              Biomech - Vals No.666
# 282855                      The Most Dangerous Commercials
#
#                        track_id  popularity  year              genre  \
# 827318   3eLDsGYTSzCMjRojGMvm7t           8  2004         psych-rock
# 717186   1H5A1GNZUv4eUf1t9RFdid          41  2002              dance
# 1056583  6MgcoY4Y8bcC5SnNwmhyIA           3  2009  progressive-house
# 1078364  40yGW7ntFLoGY3GEMcxhwM          17  2010        death-metal
# 282855   6zelGLwMV83ez2uFyUQQm8          22  2017           hardcore
#
#          danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 827318          0.678   0.598    6   -11.602     1       0.0859      0.608000
# 717186          0.700   0.504    4    -9.494     1       0.0286      0.123000
# 1056583         0.535   0.829   11    -6.568     1       0.0271      0.008450
# 1078364         0.505   0.974   10    -6.231     0       0.0717      0.000920
# 282855          0.325   0.931    4    -5.102     1       0.1000      0.000348
#
#          instrumentalness  liveness  valence    tempo  duration_ms  \
# 827318           0.007650    0.1100    0.648  114.639       467333
# 717186           0.000603    0.0924    0.588  103.880       269307
# 1056583          0.875000    0.3480    0.320  104.023       231534
# 1078364          0.013600    0.2700    0.115   99.949       447000
# 282855           0.000000    0.1160    0.314  136.056       233387
#
#          time_signature
# 827318                4
# 717186                4
# 1056583               4
# 1078364               4
# 282855                4

# %%
dataframe.loc[dataframe["mode"] == 'Major', "mode"] = 1
dataframe.loc[dataframe["mode"] == 'Minor', "mode"] = 0
dataframe.sample(5)
# Out:
#         Unnamed: 0         artist_name                 track_name  \
# 554337      554337      Zacardi Cortez  Work It Out For Me - Live
# 857208     1011588       Buddy Mullins   Life's Railway To Heaven
# 51167        51167  BJ The Chicago Kid  Sex Is the Best Breakfast
# 747027      849796             Skarnio                   Cantamos
# 245750      245750              Mitski           A Loving Feeling
#
#                       track_id  popularity  year      genre  danceability  \
# 554337  7iRYbdBA9RTLvJ3MyW9dzz          22  2022     gospel         0.280
# 857208  5YDuZmnM4rG6QvnZ1XQvGY          15  2005     gospel         0.484
# 51167   7xBKZQl0Hapw5POvr2nCQC          17  2012       soul         0.463
# 747027  6ow8ztnXjHk3bk2oBEzdB3           7  2002        ska         0.386
# 245750  5usQET86kxSpLdk7iCP1pw          55  2016  indie-pop         0.316
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 554337   0.265   10   -13.009     1       0.0422      0.722000
# 857208   0.397   11   -12.082     1       0.0275      0.743000
# 51167    0.538    4    -8.202     0       0.0679      0.279000
# 747027   0.959    4    -2.943     0       0.0466      0.020100
# 245750   0.760    9    -8.690     1       0.0564      0.000013
#
#         instrumentalness  liveness  valence    tempo  duration_ms  \
# 554337          0.000000     0.101    0.377  172.442       282417
# 857208          0.011300     0.711    0.414  131.149       265467
# 51167           0.000089     0.349    0.390   57.935       133560
# 747027          0.000030     0.198    0.645  189.402       199172
# 245750          0.000074     0.166    0.337  147.212        92090
#
#         time_signature
# 554337               5
# 857208               4
# 51167                4
# 747027               4
# 245750               4

# %%
list_of_time_signatures = dataframe['time_signature'].unique()
for i in range(len(list_of_time_signatures)):
    dataframe.loc[dataframe['time_signature'] == list_of_time_signatures[i], 'time_signature'] = i
dataframe.sample(5)
# Out:
#          Unnamed: 0                artist_name  \
# 225093       225093              Niykee Heaton
# 275670       275670              Lucas Chambon
# 626835       627136                   Montrose
# 482432       482432  The Darrow Chem Syndicate
# 1153333     1461591               Luan Santana
#
#                                    track_name                track_id  \
# 225093                               Say Yeah  07PVoBRpSEEvd7OTmUcwsp
# 275670                               Floating  5UNA196W7tYhPhs5sDgNav
# 626835          Space Station #5 - Remastered  5CYVudnz9adXy4VgdTvFbI
# 482432   Get Loose - Huda Hudia & DJ30A Remix  4EMl2tRKPOcQGQjehKO0jw
# 1153333   Conquistando O Impossível - Ao Vivo  7A462u1FbsnB0hLOe0iLBL
#
#          popularity  year      genre  danceability  energy  key  loudness  \
# 225093           36  2016      dance         0.630   0.578   11    -6.163
# 275670           27  2017     french         0.694   0.835   11    -5.862
# 626835           11  2000      blues         0.284   0.954    9    -6.406
# 482432            0  2021  breakbeat         0.734   0.917    6    -3.886
# 1153333          37  2011  sertanejo         0.436   0.716   10    -4.971
#
#          mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 225093      0       0.0306       0.15000          0.000006    0.2200    0.119
# 275670      0       0.0488       0.03470          0.115000    0.0915    0.206
# 626835      1       0.1400       0.01120          0.001890    0.7230    0.492
# 482432      1       0.0646       0.00534          0.608000    0.0434    0.860
# 1153333     1       0.0298       0.38900          0.000000    0.9140    0.237
#
#            tempo  duration_ms  time_signature
# 225093   115.016       181120               3
# 275670   123.037       226341               3
# 626835   168.618       316707               3
# 482432   132.003       278182               3
# 1153333  149.917       238880               3

# %% [markdown]
# #Popularity

# %%
dataframe.loc[dataframe['popularity'] < 57, 'popularity'] = 0
dataframe.loc[dataframe['popularity'] >= 57, 'popularity'] = 1
dataframe.loc[dataframe['popularity'] == 1]
# Out:
#          Unnamed: 0           artist_name  \
# 0                 0            Jason Mraz
# 2                 2         Joshua Hyslop
# 3                 3          Boyce Avenue
# 9                 9          Boyce Avenue
# 16               16       Gabrielle Aplin
# ...             ...                   ...
# 1156573     1467006  Penny & The Quarters
# 1156574     1467008         Amy Winehouse
# 1156575     1467010         Amy Winehouse
# 1157742     1468997       Veronica Maggio
# 1157748     1469011       Veronica Maggio
#
#                                       track_name                track_id  \
# 0                                I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 2                               Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3                                       Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 9                                         Heaven  2EKxmYmUdAVXlaHCnnW13o
# 16                                          Home  20kpTTSvI4ok6Gm1uZqtcz
# ...                                          ...                     ...
# 1156573                               You And Me  39FFlqltctkj6vkIcVgkec
# 1156574                        Our Day Will Come  4NDpn6yfD5aqafYWFEaJDz
# 1156575  Will You Still Love Me Tomorrow? - 2011  0LbK1bodGLc9xmV1cS9jvL
# 1157742                              Inga kläder  2GbyU3ZuI1gDuSCQJCXwe1
# 1157748                            Satan i gatan  3q8WojYJVZsGClFGFBYdTc
#
#          popularity  year     genre  danceability  energy  key  loudness  \
# 0                 1  2012  acoustic         0.483   0.303   11   -10.058
# 2                 1  2012  acoustic         0.409   0.234    8   -13.711
# 3                 1  2012  acoustic         0.392   0.251    4    -9.845
# 9                 1  2012  acoustic         0.619   0.280    7   -10.238
# 16                1  2012  acoustic         0.439   0.265    4   -10.720
# ...             ...   ...       ...           ...     ...  ...       ...
# 1156573           1  2011      soul         0.578   0.178    9    -7.812
# 1156574           1  2011      soul         0.705   0.634    9    -6.083
# 1156575           1  2011      soul         0.587   0.624   11    -4.657
# 1157742           1  2011   swedish         0.685   0.492    8   -10.977
# 1157748           1  2011   swedish         0.580   0.552    9    -8.673
#
#          mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           1       0.0429        0.6940          0.000000    0.1150    0.139
# 2           1       0.0323        0.3380          0.000050    0.0895    0.145
# 3           1       0.0363        0.8070          0.000000    0.0797    0.508
# 9           0       0.0317        0.7300          0.000000    0.1030    0.292
# 16          1       0.0343        0.7360          0.000000    0.0930    0.382
# ...       ...          ...           ...               ...       ...      ...
# 1156573     1       0.0330        0.9460          0.000009    0.1210    0.256
# 1156574     0       0.0282        0.0405          0.000035    0.3490    0.639
# 1156575     1       0.0250        0.1610          0.000191    0.1180    0.251
# 1157742     1       0.0314        0.4480          0.001490    0.2420    0.624
# 1157748     1       0.0276        0.3620          0.000014    0.2250    0.506
#
#            tempo  duration_ms  time_signature
# 0        133.406       240166               4
# 2        139.832       158960               3
# 3        204.961       304293               3
# 9        129.948       250063               3
# 16       140.494       247002               3
# ...          ...          ...             ...
# 1156573  111.555       160813               3
# 1156574   98.008       169373               3
# 1156575   93.428       262813               3
# 1157742  121.944       201467               3
# 1157748  122.034       195147               3
#
# [23915 rows x 20 columns]

# %% [markdown]
# #7. Model Fitting and Predicting

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier

from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key", "liveness",
            "mode", "speechiness", "tempo", "time_signature", "valence"]

# %%
training = dataframe.sample(frac = 0.8,random_state = 420)
X_train = training[features]
y_train = training['popularity']
X_test = dataframe.drop(training.index)[features]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 420)

# %% [markdown]
# #Logistic Regression

# %%
LR_Model = LogisticRegression()
LR_Model.fit(X_train, y_train)
LR_Predict = LR_Model.predict(X_valid)
LR_Accuracy = accuracy_score(y_valid, LR_Predict)
print("Accuracy: " + str(LR_Accuracy))

LR_AUC = roc_auc_score(y_valid, LR_Predict)
print("AUC: " + str(LR_AUC))
# Out:
# Accuracy: 0.9793223864671298
# AUC: 0.5

# %% [markdown]
# #Random Forest Classifier

# %%
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict)
print("AUC: " + str(RFC_AUC))

# %% [markdown]
# #K-Nearest Neighbors Classifier

# %%
KNN_Model = KNeighborsClassifier()
KNN_Model.fit(X_train, y_train)
KNN_Predict = KNN_Model.predict(X_valid)
KNN_Accuracy = accuracy_score(y_valid, KNN_Predict)
print("Accuracy: " + str(KNN_Accuracy))

KNN_AUC = roc_auc_score(y_valid, KNN_Predict)
print("AUC: " + str(KNN_AUC))

# %% [markdown]
# #Decision Tree Classifier

# %%
DT_Model = DecisionTreeClassifier()
DT_Model.fit(X_train, y_train)
DT_Predict = DT_Model.predict(X_valid)
DT_Accuracy = accuracy_score(y_valid, DT_Predict)
print("Accuracy: " + str(DT_Accuracy))

DT_AUC = roc_auc_score(y_valid, DT_Predict)
print("AUC: " + str(DT_AUC))

# %% [markdown]
# #Linear Support Vector Classification

# %%
training_LSVC = training.sample(10000)
X_train_LSVC = training_LSVC[features]
y_train_LSVC = training_LSVC['popularity']
X_test_LSVC = dataframe.drop(training_LSVC.index)[features]
X_train_LSVC, X_valid_LSVC, y_train_LSVC, y_valid_LSVC = train_test_split(
    X_train_LSVC, y_train_LSVC, test_size = 0.2, random_state = 420)

# %%
LSVC_Model = DecisionTreeClassifier()
LSVC_Model.fit(X_train_LSVC, y_train_LSVC)
LSVC_Predict = LSVC_Model.predict(X_valid_LSVC)
LSVC_Accuracy = accuracy_score(y_valid_LSVC, LSVC_Predict)
print("Accuracy: " + str(LSVC_Accuracy))

LSVC_AUC = roc_auc_score(y_valid_LSVC, LSVC_Predict)
print("AUC: " + str(LSVC_AUC))

# %% [markdown]
# #XGBOOST

# %%
XGB_Model = XGBClassifier(objective = "binary:logistic", n_estimators = 10, seed = 123)
XGB_Model.fit(X_train, y_train)
XGB_Predict = XGB_Model.predict(X_valid)
XGB_Accuracy = accuracy_score(y_valid, XGB_Predict)
print("Accuracy: " + str(XGB_Accuracy))

XGB_AUC = roc_auc_score(y_valid, XGB_Predict)
print("AUC: " + str(XGB_AUC))

# %% [markdown]
# #8. Model Performance Summary

# %%
model_performance_accuracy = pd.DataFrame({'Model': ['LogisticRegression',
                                                      'RandomForestClassifier',
                                                      'KNeighborsClassifier',
                                                      'DecisionTreeClassifier',
                                                      'LinearSVC',
                                                      'XGBClassifier'],
                                            'Accuracy': [LR_Accuracy,
                                                         RFC_Accuracy,
                                                         KNN_Accuracy,
                                                         DT_Accuracy,
                                                         LSVC_Accuracy,
                                                         XGB_Accuracy]})

model_performance_AUC = pd.DataFrame({'Model': ['LogisticRegression',
                                                      'RandomForestClassifier',
                                                      'KNeighborsClassifier',
                                                      'DecisionTreeClassifier',
                                                      'LinearSVC',
                                                      'XGBClassifier'],
                                            'AUC': [LR_AUC,
                                                         RFC_AUC,
                                                         KNN_AUC,
                                                         DT_AUC,
                                                         LSVC_AUC,
                                                         XGB_AUC]})

# %%
model_performance_accuracy.sort_values(by = "Accuracy", ascending = False)

# %%
model_performance_AUC.sort_values(by = "AUC", ascending = False)

# %% [markdown]
# #Deep Learning Training

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#Library for modelling
from sklearn.preprocessing import LabelEncoder #Encodes Categorical Data into Numerical
from sklearn.model_selection import train_test_split #For spliting data into training and testing sets

# %%
#Libraries for Deep Learning
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# %% [markdown]
# #Splitting data

# %%
training_data, testing_data = train_test_split(dataframe, test_size=0.2, random_state=25)

print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")

testing_data
# Out:
# No. of training examples: 927811
# No. of testing examples: 231953
#         Unnamed: 0      artist_name  \
# 909855     1090688          BIGBANG
# 240619      240619       Nels Cline
# 641204      645173   Udo Lindenberg
# 670395      739787    Radio Birdman
# 993919     1217631  Dynamite Deluxe
# ...            ...              ...
# 554676      554676     Blue Highway
# 715175      802783  Frédéric Chopin
# 551358      551358            Drics
# 720901      809617     Dom & Roland
# 883974     1055742         Witchery
#
#                                                track_name  \
# 909855                                    Victory (Intro)
# 240619                                        Secret Love
# 641204                                              Cello
# 670395                                               I-94
# 993919                                      Mein Flow ist
# ...                                                   ...
# 554676                           On The Roof Of The World
# 715175  Chopin: 24 Preludes, Op. 28: No. 13 in F-Sharp...
# 551358                                             Jungle
# 720901                                       Twisted City
# 883974                           The Wait of the Pyramids
#
#                       track_id  popularity  year          genre  danceability  \
# 909855  3BH7dgnovhpgTH0p8IrTog           0  2006          k-pop         0.810
# 240619  1mMNBC1caDrGaZHVrae8rD           0  2016         guitar         0.452
# 641204  0PBOJadCOGsJGUv6zqr8PO           0  2000         german         0.444
# 670395  2SInWW7rJrIc1G653BoH3U           0  2001          blues         0.352
# 993919  5QPLBwhsjKFa6Q1n3kV3i5           0  2008         german         0.408
# ...                        ...         ...   ...            ...           ...
# 554676  6TDOeNy20BOWkBZjK33obX           0  2022         gospel         0.608
# 715175  74VNF9Q1dV144F5fS0KmdD           0  2002      classical         0.309
# 551358  0uEHgbk1Db5y6jQgyelmbQ           0  2022         french         0.812
# 720901  1IaPJEfbm9zSk9rFoGGHJd           0  2002  drum-and-bass         0.522
# 883974  7jT82mcKgf3jlyuoD18eGO           0  2006    black-metal         0.324
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 909855  0.6990   11    -4.565     1       0.0610      0.028700
# 240619  0.1210    7   -20.893     1       0.0565      0.957000
# 641204  0.4830    6   -10.146     0       0.0283      0.662000
# 670395  0.9560    9    -4.436     0       0.2380      0.013700
# 993919  0.6190    9    -7.474     0       0.2750      0.027800
# ...        ...  ...       ...   ...          ...           ...
# 554676  0.7950   10    -4.974     1       0.0299      0.191000
# 715175  0.0026    3   -35.780     1       0.0378      0.994000
# 551358  0.3620    9   -16.399     1       0.1010      0.751000
# 720901  0.8870    8   -13.630     1       0.0737      0.000066
# 883974  0.9680    8    -4.523     1       0.0673      0.000046
#
#         instrumentalness  liveness  valence    tempo  duration_ms  \
# 909855          0.000000    0.0864   0.4850   90.027       112118
# 240619          0.840000    0.1100   0.3980   82.291       270267
# 641204          0.206000    0.1160   0.4050   86.416       180560
# 670395          0.000173    0.2160   0.2990  176.381       216587
# 993919          0.000041    0.3360   0.5380   80.069       215400
# ...                  ...       ...      ...      ...          ...
# 554676          0.036200    0.1220   0.9090  119.797       191701
# 715175          0.878000    0.0828   0.1250   67.257       209853
# 551358          0.824000    0.0900   0.0531  120.103       176219
# 720901          0.871000    0.0933   0.5180  171.957       518586
# 883974          0.848000    0.4220   0.2070  105.080       235520
#
#         time_signature
# 909855               3
# 240619               3
# 641204               3
# 670395               3
# 993919               3
# ...                ...
# 554676               3
# 715175               3
# 551358               3
# 720901               3
# 883974               4
#
# [231953 rows x 20 columns]

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1664
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 166529 (650.50 KB)
# Trainable params: 166529 (650.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5'
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %% [markdown]
# #Training Model

# %%
NN_model.fit(X_train, y_train, epochs=6, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/6
# 18552/18557 [============================>.] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 1: val_loss improved from 0.02067 to 0.02065, saving model to Weights-001--0.02065.hdf5
# 18557/18557 [==============================] - 89s 5ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206
# Epoch 2/6
# 18552/18557 [============================>.] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 2: val_loss did not improve from 0.02065
# 18557/18557 [==============================] - 83s 4ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0207 - val_mean_absolute_error: 0.0207
# Epoch 3/6
# 18546/18557 [============================>.] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 3: val_loss improved from 0.02065 to 0.02062, saving model to Weights-003--0.02062.hdf5
# 18557/18557 [==============================] - 80s 4ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206
# Epoch 4/6
# 18553/18557 [============================>.] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 4: val_loss did not improve from 0.02062
# 18557/18557 [==============================] - 83s 4ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0209 - val_mean_absolute_error: 0.0209
# Epoch 5/6
# 18554/18557 [============================>.] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 5: val_loss did not improve from 0.02062
# 18557/18557 [==============================] - 83s 4ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206
# Epoch 6/6
# 18548/18557 [============================>.] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.0209
# Epoch 6: val_loss improved from 0.02062 to 0.02062, saving model to Weights-006--0.02062.hdf5
# 18557/18557 [==============================] - 82s 4ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - val_loss: 0.0206 - val_mean_absolute_error: 0.0206
